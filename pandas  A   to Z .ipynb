# %%
import pandas as pd

var=pd.Series([1,2,3,4,5],index=['a','b','c','d','w'], dtype="object")
print(var)
print(len(var))
print (var[2])#indexing
# Out:
# a    1
# b    2
# c    3
# d    4
# w    5
# dtype: object
# 5
# 3
# C:\Users\junaidwar\AppData\Local\Temp\ipykernel_8608\2527849621.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print (var[2])

# %%
v=[1,2,3,1]
v1=pd.DataFrame(v)
print(v1)
v2={"a":[1,2,3,4,5,6],"b":[7,8,9,3,4,5]}

v3=pd.DataFrame(v2,index=["a","b","c","d","g","f"])
print(v3)
print(v2["a"][2])
print(v2)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  1
#    a  b
# a  1  7
# b  2  8
# c  3  9
# d  4  3
# g  5  4
# f  6  5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 8
#       6 v3=pd.DataFrame(v2,index=["a","b","c","d","g","f"])
#       7 print(v3)
# ----> 8 print(v2["a"][2],center=50)
#
# TypeError: print() got an unexpected keyword argument 'center'

# %%
import pandas as pd
var=pd.DataFrame({"name":["junaid","ahmad","war"],"age":[13,12,17],"marks":[30,40,50]},index=[1,2,3])
print(var["name"][2])
print(var["marks"])
# Out:
# ahmad
# 1    30
# 2    40
# 3    50
# Name: marks, dtype: int64

# %%
import pandas as pd
var1=pd.DataFrame({"a":[1,2,3,4,5],"b":[6,7,8,9,0]},index=["a","b","c","d","e"])
var1["c"]=var1["a"]+var1["b"]
var1["d"]=var1["a"]-var1["b"]
var1["e"]=var1["a"]/var1["b"]
var1["f"]=var1["a"]*var1["b"]

var1
var1["pyton"]=var1["a"]>=5
var1
# Out:
#    a  b   c  d         e   f  pyton
# a  1  6   7 -5  0.166667   6  False
# b  2  7   9 -5  0.285714  14  False
# c  3  8  11 -5  0.375000  24  False
# d  4  9  13 -5  0.444444  36  False
# e  5  0   5  5       inf   0   True

# %%
import pandas as pd
var1=pd.DataFrame({"a":[1,2,3,4,5],"b":[6,7,8,9,0]},index=["a","b","c","d","e"])
var1.insert(2,"python",[12,13,13,14,15])
var1.insert(3,"c",var1["a"][0:2])#limit used 
var1
var1.pop("b")
var1
del var1["python"]
var1
# Out:
#    a    c
# a  1  1.0
# b  2  2.0
# c  3  NaN
# d  4  NaN
# e  5  NaN

# %%
import pandas as pd
var1=pd.DataFrame({"a":[1,2,3,4,5],"b":[6,7,8,9,0]},index=["a","b","c","d","e"])
var1.to_csv("test")

# %%
import pandas as pd
 # pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",nrows=10,usecols=["Index","Customer Id","First Name","City"],index_col=["First Name"],skiprows=[1])
pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",nrows=10,index_col="First Name")
pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",header=[2])
pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",names=["co1","co2","co3,co4","co5","co6","co7","co8","co9","co10","co11","co12","co",])
pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",dtype={"Index":"float"})
# Out:
#     Index      Customer Id First Name Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston    Lozano
# 2     3.0  6F94879bDAfE5a6        Roy       NaN
# 3     NaN                1          1     Olsen
# 4     5.0              NaN        NaN       NaN
# ..    ...              ...        ...       ...
# 95   96.0  cb8E23e48d22Eae       Karl     Greer
# 96   97.0  CeD220bdAaCfaDf       Lynn  Atkinson
# 97   98.0  28CDbC0dFe4b1Db       Fred    Guerra
# 98   99.0  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99  100.0              NaN   Clarence    Haynes
#
#                             Company               City              Country  \
# 0                   Rasmussen Group       East Leonard                Chile
# 1                       Vega-Gentry  East Jimmychester             Djibouti
# 2                                12                NaN  Antigua and Barbuda
# 3   Dominguez, Mcmillan and Donovan         Bensonview   Dominican Republic
# ...

# %%
#pandas functions
q=pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",nrows=10)
q
q.index
q.columns
q.describe()
q.head(11)
q.tail(1)
q[3:7]
q.to_numpy()
q.sort_index(axis=0,ascending=1)
# q ["Index"][0]=["py"]
# q.loc[0,["Index"="pyt"]]
q.rename(columns={"Index":"py"})
q.loc[:6,["Customer Id"]]#is used to acces data using column name
q.iloc[0:3]# access data using indexs

q=pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",nrows=10)
q.drop("Country",axis=1)#must use axis to remove
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0    1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1    2.0  1Ef7b82A4CAAD10    Preston     Lozano
# 2    3.0  6F94879bDAfE5a6        Roy        NaN
# 3    NaN                1          1      Olsen
# 4    5.0              NaN        NaN        NaN
# 5    6.0              NaN        NaN        NaN
# 6    7.0  EA4d384DfDbBf77          1          1
# 7    8.0  0e04AFde9f225dE      Brett     Mullen
# 8    NaN  C2dE4dEEc489ae0     Sheryl     Meyers
# 9   10.0              NaN        NaN  Gallagher
#
#                            Company               City                 Phone 1  \
# 0                  Rasmussen Group       East Leonard            229.077.5154
# 1                      Vega-Gentry  East Jimmychester              5153435776
# 2                               12                NaN                   -1199
# 3  Dominguez, Mcmillan and Donovan         Bensonview  001-808-617-6467x12895
# ...

# %%
#handling missing data using fina or dropnaa
import pandas as pd
var=pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",nrows=17)
# var.dropna(how="all")
# var.dropna(subset=["Customer Id"])
var.dropna(thresh=8)
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0     1.0  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1     2.0  1Ef7b82A4CAAD10    Preston     Lozano
# 2     3.0  6F94879bDAfE5a6        Roy        NaN
# 3     NaN                1          1      Olsen
# 4     5.0              NaN        NaN        NaN
# 6     7.0  EA4d384DfDbBf77          1          1
# 7     8.0  0e04AFde9f225dE      Brett     Mullen
# 8     NaN  C2dE4dEEc489ae0     Sheryl     Meyers
# 9    10.0              NaN        NaN  Gallagher
# 10    NaN  216E205d6eBb815       Carl  Schroeder
# 11   12.0  CEDec94deE6d69B      Jenna     Dodson
# 12   13.0  e35426EbDEceaFF     Tracey       Mata
# 13   14.0  A08A8aF8BE9FaD4   Kristine        Cox
# 14   15.0  6fEaA1b7cab7B6C      Faith       Lutz
# 15    NaN  8cad0b4CBceaeec    Miranda    Beasley
# 16   17.0  a5DC21AE3a21eaA   Caroline      Foley
#
#                             Company               City              Country  \
# ...

# %%
#fillna

import pandas as pd
var=pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",nrows=17)
# var.fillna({"Last Name":"jni","City":"srinagr"})
# var.bfill(axis=1)
var.fillna(12,inplace=True)



# var.fillna(method="ffill")
# var.fillna(method="bfill")
# var.bfill()#also use like this

# %%
import pandas as pd
var=pd.read_csv("C:/Users/junaidwar/Downloads/customers-100.csv",nrows=17)

# %%
#merge and concate
import pandas as pd
var1=pd.DataFrame({"name":["jani","mani","wani"],"so":["mumbi","lundon","newslnd"]})

var2=pd.DataFrame({"name":["jani","mani","dani"],"city":["mumbi","lundon","africa"]})
pd.merge(var1,var2,on="name",how="outer",indicator=True)


#merge and concate
import pandas as pd
var1=pd.DataFrame({"name":["jani","mani","wani"],"so":["mumbi","lundon","newslnd"]})

var2=pd.DataFrame({"name":["jani","mani","dani"],"city":["mumbi","lundon","austra"]})
pd.merge(var1,var2,left_index=True,right_index=True)
# Out:
#   name_x       so name_y    city
# 0   jani    mumbi   jani   mumbi
# 1   mani   lundon   mani  lundon
# 2   wani  newslnd   dani  austra

# %%
#concatenate
a=pd.DataFrame({"a":[1,23,4,5],"b":[21,22,23,24]})
b=pd.DataFrame({"a":[1,23,4,6],"b":[25,26,27,28]})
pd.concat([a,b],axis=1,join="outer").
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[102], line 4
#       2 a=pd.DataFrame({"a":[1,23,4,5],"b":[21,22,23,24]})
#       3 b=pd.DataFrame({"a":[1,23,4,6],"b":[25,26,27,28]})
# ----> 4 pd.concat([a,b],axis=1,join="left")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...

# %%
#jions
